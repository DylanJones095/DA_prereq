# %%
# Cell 1: sucessfully run a python code

x = 7
y = 4

sum = x + y

print('the sum of {0} and {1} is {2}' .format(x, y, sum))
# Out:
# the sum of 7 and 4 is 11

# %% [markdown]
# # Cell 2: introduce yourself
#
# my name is Dylan Jones. I play Street Fighter in my spare time and I have an adorable grey cat. I'm interested in the practical application of data analysis and how my own understanding can grow from logics and experience using python.
